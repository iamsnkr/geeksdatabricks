# %%
# %sql

USE DATABASE geek_marts;

# %%
# %sql
CREATE TABLE IF NOT EXISTS Dim_Airport (
  code STRING,
  city STRING,
  country STRING,
  airport STRING
) USING DELTA LOCATION 'abfss://marts@geekadlsstoragesink.dfs.core.windows.net/airport'

# %%
# %sql
INSERT OVERWRITE Dim_Airport
SELECT code ,city ,country ,airport 
FROM  cleansed_geekcoders.airport
