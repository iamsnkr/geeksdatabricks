# %%
# %sql

USE DATABASE geek_marts;

# %%
# %sql
CREATE TABLE IF NOT EXISTS Dim_Airlines (
  iata_code STRING,
  icao_code STRING,
  name STRING
) USING DELTA LOCATION 'abfss://marts@geekadlsstoragesink.dfs.core.windows.net/airlines'

# %%
# %sql
INSERT OVERWRITE Dim_Airlines
SELECT iata_code ,icao_code, name 
FROM  cleansed_geekcoders.airlines
