# %%
# %sql

USE DATABASE geek_marts;

# %%
# %sql
CREATE TABLE IF NOT EXISTS Dim_UniqueCarrier (
  code STRING,
  description STRING
) USING DELTA LOCATION 'abfss://marts@geekadlsstoragesink.dfs.core.windows.net/uniquecarrier'

# %%
# %sql
INSERT OVERWRITE Dim_UniqueCarrier
  SELECT
    code,
    description
  FROM cleansed_geekcoders.unique_carriers
